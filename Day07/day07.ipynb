# %%
import re

# %%
with open("test.txt") as fp:
    rawd = fp.read()

# %%
with open("test.txt") as file:
    rawd = [line.strip() for line in file]

# %%
print(rawd)
# Out:
# ['bright white bags contain 1 shiny gold bag.']

# %%
def trnsform(data2trns):
    x = []
    for i in data2trns:
        i = str(i.replace("bags","bag"))
        i = str(i.replace(",",""))
        i = str(i.replace(".",""))
        x.append(i)
    return x

# %%
trnsform(rawd)
# Out:
# ['bright white bag contain 1 shiny gold bag']

# %%
#EZ ITT A PART01 FV KODJANAK PROTOTIPUSA

rules = trnsform(rawd)
for i in rules:
    if "other" not in i:
        print(i)
        print(i.split("bag",1)[0])
        holdit = i.split("contain ",1)[1].split(" ",1)[0]
        print(holdit)
        print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[0])
        try:
            print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0])
        except:
            None
        try:
            print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0])
        except:
            None
        try:
            print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
                .split(" ",1)[0])
        except:
            None
        print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
                .split(" ",1)[1].split(" bag ",1)[0])
        print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
                .split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0])
        print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
                .split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag",1)[0])
# Out:
# bright white bag contain 1 shiny gold bag
# bright white
# 1
# shiny gold bag
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-269-900d33a53c19> in <module>
#      22         except:
#      23             None
# ---> 24         print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
#      25                 .split(" ",1)[1].split(" bag ",1)[0])
#      26         print(i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
#
# IndexError: list index out of range

# %%
part01(rawd)
# Out:
# vibrant aqua

# %%
        thirdinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1]\
                .split(" ",1)[0]
        thirdinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
        fourthinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
        fourthinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag",1)[0])
# Out:
#   File "<ipython-input-224-b1600660b111>", line 5
#     fourthinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag",1)[0])
#                                                                                                                                                                                                  ^
# SyntaxError: unmatched ')'

# %%
#EZ ITT A PART01 FV KODJANAK PROTOTIPUSA

rules = trnsform(rawd)
endofbags = 0
for i in rules:
    if "other" not in i:
        containerbag = i.split("bag",1)[0]
        try:
            firstinternalbagnum = i.split("contain ",1)[1].split(" ",1)[0]
            firstinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[0]
        except:
            firstinternalbagnum = "0"
            firstinternalbagname = "None"
            endofbags = 1
        if endofbags == 0:
            try:
                secondinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
                secondinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
            except:
                endofbags = 1
        if endofbags == 0:
            try:
                thirdinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
                thirdinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
            except:
                endofbags = 1
        if endofbags == 0:
            try:
                thirdinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                    .split(" bag ",1)[1].split(" ",1)[0]
                thirdinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                    .split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
            except:
                endofbags = 1
        if endofbags == 0:
            try:
                fourthinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                    .split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
                fourthinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                    .split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag",1)[0]
            except:
                endofbags = 1
        print(i)
        print(containerbag)
        print(firstinternalbagnum)
        print(firstinternalbagname)
        print(secondinternalbagnum)
        print(secondinternalbagname)
        print(thirdinternalbagnum)
        print(thirdinternalbagname)
        print(fourthinternalbagnum)
        print(fourthinternalbagname)
# Out:
# ted chartreuse
# h
# h
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# i
# i
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# n
# n
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# y
# y
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
#
#
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# g
# g
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# o
# o
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# l
# l
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# d
# d
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
#
#
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# b
# b
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# a
# a
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# muted chartreuse
# g
# g
# 0
# None
# 2
# muted teal
# 1
# dim magenta
# 1
# ...

# %%
#EZ ITT A PART01 FV KODJANAK PROTOTIPUSA

rules = trnsform(rawd)
endofbags = 0

if "other" not in i:
    containerbag = i.split(" bag ",1)[0]
    try:
        firstinternalbagnum = i.split("contain ",1)[1].split(" ",1)[0]
        firstinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[0]
    except:
        firstinternalbagnum = "0"
        firstinternalbagname = "None"
        endofbags = 1
    if endofbags == 0:
        try:
            secondinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
            secondinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
        except:
            endofbags = 1
    if endofbags == 0:
        try:
            thirdinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
            thirdinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
        except:
            endofbags = 1
    if endofbags == 0:
        try:
            thirdinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                .split(" bag ",1)[1].split(" ",1)[0]
            thirdinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                .split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[0]
        except:
            endofbags = 1
    if endofbags == 0:
        try:
            fourthinternalbagnum = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                .split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[0]
            fourthinternalbagname = i.split("contain ")[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1]\
                .split(" bag ",1)[1].split(" ",1)[1].split(" bag ",1)[1].split(" ",1)[1].split(" bag",1)[0]
        except:
            endofbags = 1
    print(i)
    print(containerbag)
    print(firstinternalbagnum)
    print(firstinternalbagname)
    print(secondinternalbagnum)
    print(secondinternalbagname)
    print(thirdinternalbagnum)
    print(thirdinternalbagname)
    print(fourthinternalbagnum)
    print(fourthinternalbagname)
# Out:
# bright white bag contain 1 shiny gold bag
# bright white
# 1
# shiny gold bag
# 4
# muted yellow bag
# muted yellow bag
# dim magenta
# 1
# muted chartreuse
